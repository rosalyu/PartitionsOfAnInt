# %%
# C O M M A N D S
 
# IN LIST?: command=[word]
# SEARCH: command=search
# RANDOM: command='random'
# ALL W. WITH SAME LEN: command=[int]

# FIRST SIMILAR: command='first'
# LAST SIMILAR: command='last'
# MIDDLE SIMILAR: command='middle'

# SORT BY ALPH: command='alph'
# SORT TYPE BY ALPH: command='alph.[type]'

# NUM OF TYPES: command='stats'
# LETTER STATS: command='letters'

command=input() or 'list'
word=input() or 'something'

list=['declutter.v','elaborate.v','prohibit.v','inevitable.a','assurance.n','apply.v','derive.v','postpone.v','refute.v','in regard to.p','deprecate.v','contention.n','inanimate.a','negligence.n','imposter.n','audacity.n','douchebag.n','prerequisite.n','compulsion.n','remark.n','deteriorate.v','arbitrary.a','persistent.a','concievable.a','shenanigan.n','obscene.a','curfew.n','tenant.n','my condolences.p','condolence.n','scatter.v','mesmerizing.a','friction.n','encounter.v','penetrate.v','contagious.a','compliant.a','consensual.a','inquire.v','accomplice.n','incarcerated.a','percussion instrument.n','in advance.p','cheeky.a','resentment.n','agitated.a','condescending.a','consent.a','ambiguous.a','frugal.a','immerse.v','pertain.v','digress.v','allegedly.a','vindictive.a','pervasive.a','nuisance.n','infidelity.n','perpetuate.n','contentious.a','allegation.n','descendant.n','frantic.a','in the course of.p','resilient.a','shallow.a','emerge.v','confine.v','proficient.a','reluctant.a','evade.v','seldom.a','intrinsic.a','recline.v','in defiance of.p','exhilarate.v','defy.v','complexion.n','hence.p','bear.v','tangible.a','humongous.a','fierce.a','inherent.a','quirky.a','pitfall.n','accumulation.n','accustom.v','converse.a','condemn.v','dote.v','plead.v','relent.v','bestow.v','oblivion.n','confinement.n','chuckle.v','bribery.n','contemplate.v','contrary.a','succinct.a','extrapolate.a','emote.a','petty.a','former.a','glimpse.n','amorous.a','actuary.n','accountable.a','hyperbolic.a','redundant.a','alluring.a','relentless.a','mitigation.n','ordeal.n','convey.v','loathe.v','impaired.a','lackluster.a','oblivious.a','ornate.a','petrified.a','inquisitive.a','embark.v','spree.n','rigid.a','firm.a','saturate.v','albeit.p','enticing.a','illegible.a','adamant.a','endeavour.n','endeavour.v','it occured to me.p','mandatory.a','revelation.a','epiphany.n','erroneous.a','interference.n','implication.n','abbreviate.v','innate.a','sophisticated.a','excel.v','conduct.v','redeem.v','apparent.a','constraint.n','lawnmower.n','defer.v','negate.v','query.n','amass.v','susceptible.a','kinky.a','in vain.p','mortified.a','repugnant.a','quiver.v','conquer.v','prior to.p','unsolicited.a','assertive.a','affiliate.v','aisle.n','accentuate.v','pantry.n','holistic.a','frankly.a','considerate.a','demeanour.n','reinforce.v','dread.n','seamless.a','weep.v','boater.n','disenchantment.n','enchant.v','prudent.a','enunciate.v','integrity.n','reckon.v','caterpillar.n','mighty.a','intertwine.v','convoluted.a','contentment.n','conjecture.n','amplify.v','abyss.n','employ.v','vast.a','impudent.a','elude.v','acquire.v','start from scratch.p','standoffish.a','conscientious.a','elate.v','incline.v','disinclined.a','meticulous.a','stride.n','unyielding.a','demean.v','litter.v','effusive.a','appalling.a','content.a','adhere.v','anticipate.v','respective.a','conversion.n','pathetic.a','gratification.n','remorse.n','contraceptive.n','despicable.a','rehearse.v','toddler.n','solitary.a','escort.v','heed.v','fraud.n','untangle.v','parakeet.n','prospect.v','precarious.a','prerogative.n','tuck.v','appease.v','ambivalent.a','consult.v','prevail.v','concede.v','contemptuous.a','neat.a','comprise.v','permit.v','serpent.n','mere.a','realm.n','attainable.a','fathdom.v','finesse.n','adjacent.a','exploitation.n','insistent.a','concession.n','blackmail.n','complacent.a','notorious.a','infamous.a','ascend.v','jigsaw.n','disguise.n','captivated.a','agony.n','baffling.a','whatsoever.p','fluctuate.v','subsequent.a','tender.v','etiology.n','attentuate.v','barking up the wrong tree.s','get off ones backside.s','veer onto the wrong trail.s','veer between.p','veer.v','acquisition.n','trove.n','impediment.n','initial.a','prolific.a','aversion.n','collaboration.n','prevalence.n','resign.v','adapted.a','pavement.n','threshold.n','apt.a','hurriedly.a','cognition.n','profuse.a','brake.v','composure.n','obstructive.a','adept.a','fencer.n','mischief.n','gross.a','solitude.n','twofold.a','thus.p','ribbon.n','stilted.a','recess.n','executive.a','resemble.v','the latter.p','apathetic.a','gait.n','vultute.n','refrain.v','incredulous.a','ponder.v','adapt.v','mischievous.a','compound.v','dismiss.v','striking.a','obscure.a','obscure.v','withdrawal.n','sideline.v','sideline.n','compel.v','profound.a','overt.a','subtle.a','decipher.v','ambassador.n','self-proclaimed.a','contingency.n','gnaw.v','embolden.v','offbeat.a','uncharted.a','exonerate.v','ominous.a','infatuate.v','shackle.n','crude.a','account for.v','adverse.a','deem.v','witty.a','contrarian.a','contrarian.n','cranky.a','deliberate.a','accelerate.v','whatnot.p','respite.n','futile.a','thyroid.n','cartilage.n','decompose.v','retention.n','tamper.v','testimony.n','compose.v','amendment.n','instance.v','examine.v','allocate.v','attend to.v','tempt.v','peculiar.a','impend.v','bundle.v','abundant.a']

#SET VARIABLES

#similar words
first=len(word)
last=len(word)
middle=len(word)

#print list
if command=='list':
   for w in list:
       print(w)
       
#search word
if command=='search':
   count=0
   for w in list: 
      count+=1
      if w[:-2]==word:
         print('found on position:',count) 
         print('')    

#select random word      
if command=='random':
   import random
   print(random.choice(list))     
   print('')
 
#ALPHABET
#alphabetical order        
if command=='alph':
   from operator import itemgetter 
   for w in sorted(list):
       print(w)  
   print('')       
#nouns alph
if command=='alph.n':
   from operator import itemgetter 
   new_list=[]
   for w in list: 
       if w[-2:]=='.n':
          new_list.append(w)
   print(len(new_list),'nouns in total.') 
   print('')     
   for w in sorted(new_list):
       print(w) 
   print('')      
#verbs alph
if command=='alph.v':
from operator import itemgetter 
   new_list=[]
   for w in list: 
       if w[-2:]=='.v':
          new_list.append(w)
   print(len(new_list),'verbs in total.') 
   print('')          
   for w in sorted(new_list):
       print(w) 
   print('')        
#adjectives alph
if command=='alph.a':
   from operator import itemgetter 
   new_list=[]
   for w in list: 
       if w[-2:]=='.a':
          new_list.append(w)
   print(len(new_list),'adjectives in total.') 
   print('')          
   for w in sorted(new_list):
       print(w) 
   print('')    
#phrases alph
if command=='alph.p':
   from operator import itemgetter 
   new_list=[]
   for w in list: 
       if w[-2:]=='.p':
          new_list.append(w)
   print(len(new_list),'phrases in total.') 
   print('')         
   for w in sorted(new_list):
       print(w)  
   print('')  
#sayings alph
if command=='alph.s':
   from operator import itemgetter 
   new_list=[]
   for w in list: 
       if w[-2:]=='.s':
          new_list.append(w)
   print(len(new_list),'sayings in total.') 
   print('')         
   for w in sorted(new_list):
       print(w)         
   print('')


#SIMILAR WORDS
#FIRST
if command=='first':  
      #text
      for a in list:
            if a[:first]==word[:first] and a!=word:
               print('FIRST:')
               break
            else:
               continue
      #count
      count=0         
      for a in list:
            if a[:first]==word[:first] and a!=word:
               count+=1
      print(count,'found.')  
      print(' ') 
      #code          
      for a in list:
            if a[:first]==word[:first] and a!=word:
               
               print(a)                                    
      print(' ')   

#LAST     
elif command=='last':  
      #text
      for a in list:
            if a[-last-2:-2]==word[-last:] and a!=word:
               print('LAST:')
               break
            else:
               continue
      #count
      count=0
      for a in list:
            if a[-last-2:-2]==word[-last:] and a!=word:
               count+=1                    
      print(count,'found.')
      print('')
      #code
      for a in list:
            if a[-last-2:-2]==word[-last:] and a!=word:
               print(a)         
      print(' ')             

#MIDDLE
elif command=='middle':
     #text
     arbitr=0
     for w in list:
        d=-1
        while d in range(-1,int(middle+1+len(w)-2*middle)):
             d+=1
             if word==w[d:d+middle]:
                 arbitr+=1
                 break           
     if arbitr>0:
        print('MIDDLE:')
     #count
     count=0
     for w in list:
        d=-1
        while d in range(-1,int(middle+1+len(w)-2*middle)):
             d+=1
             if word==w[d:d+middle]:
                count+=1
                break 
     print(count,'found.') 
     print('')
     #code
     for w in list:
        d=-1
        while d in range(-1,int(middle+1+len(w)-2*middle)):
             d+=1
             if word==w[d:d+middle]:
                print(w)             
     print(' ')
    
#word type statistics
if command=='stats':
   n=0
   v=0
   a=0
   p=0
   s=0
   for w in list:
       if w[-2:]=='.n':
          n+=1
       elif w[-2:]=='.v':
          v+=1
       elif w[-2:]=='.a':  
          a+=1
       elif w[-2:]=='.p':  
          p+=1  
       elif w[-2:]=='.s':  
          s+=1 
   print('STATISTICS:') 
   print('')       
   print('nouns:'+str(n))
   print('verbs:'+str(v))
   print('adjectives:'+str(a))  
   print('phrases:'+str(p))   
   print('sayings:'+str(s))  
   print('')
   print('total:'+str(len(list)))

#LETTER STATS
def middle(let):
    #count
    count=0
    for w in list:
       d=-1
       while d in range(-1,int(len(w)-1)):
            d+=1
            if w[d]==let:
               count+=1       
    print(str(let)+':'+str(count))
    
if command=='letters':
   alphabet='abcdefghijklmnopqrstuvwxyz'
   print('LETTER STATISTICS:')
   print('')
   pos=-1
   while pos<25:
         pos+=1
         middle(alphabet[pos])
   print('')      
                         
#number of letters
elif command.isdigit():
     m=0
     for a in list:
        if len(a)==int(command)+2:
           m+=1
     if m==0:
        print('No elements with length',command+'.')
     elif m==1:
        print(m,'element with length',command+'.')  
     else:  
        print(m,'elements with length',command+'.')  
     print('')      
     for a in list:
        if len(a)==int(command)+2:
           print(a)
    
#word in list or not
else: 
   ran=0
   for w in list:
      if w[:-2]==command:
         print('"'+command+'"','is in list.')
         ran+=1
   if ran==0 and command!='first' and command!='last' and command!='middle' and command!='search' and command!='stats' and command!='random' and command!='alph' and command!='alph.n' and command!='alph.v' and command!='alph.a' and command!='alph.p' and command!='alph.s' and command!='list' and command!='letters':
      print('"'+command+'"','is not in list.')

#words in total
if command!='stats':   
   print(str(len(list)),'words in total.')
   print(' ')


#double words in list
   num=''
   for x in range(len(list)):
       for y in range(len(list)):
          if list[x]==list[y] and x!=y:
              num=1
              break
   if num==1:
          print('DOUBLE WORDS:')              

   xx=''
   yy=''
   for x in range(len(list)):
       for y in range(len(list)):
          if list[x]==list[y] and x!=y and xx!=y and yy!=x:
              print(list[x],'on positions',x+1,'and',str(y+1)+'.')
              xx=x
              yy=y
          else:
              continue   
   print('')
      
#find invalid word types
m=0
for word in list:
    if word[-2:]!='.n' and word[-2:]!='.a' and word[-2:]!='.p' and word[-2:]!='.v' and word[-2:]!='.s':
       m+=1
if m>0:      
   print('INVALID WORD TYPE:')

num=0
for word in list:
    num+=1
    if word[-2:]!='.n' and word[-2:]!='.a' and word[-2:]!='.p' and word[-2:]!='.v' and word[-2:]!='.s':
        print(word,'on position',num)
# Out:
# random
# integrity
